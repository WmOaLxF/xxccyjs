# %%
import requests
import re 
from bs4 import BeautifulSoup 
import pandas as pd

# %%
course_d={'信息存储与检索':'_52687_1',
         'Python数据分析':'_52694_1'}

# %%
course_name='Python数据分析'

# %% [markdown]
# ## 爬取视频URL

# %% [markdown]
# 输入教学网cookie

# %%
bdl_cookie='JSESSIONID=5A1E251BC2C98390268BD65E99A293ED; _ga=GA1.3.66611564.1598972936; Hm_lvt_c7896bb34c3be32ea17322b5412545c0=1606471943; PORTALLANG=zh; JWTUser={"account":"1800018615","id":508999,"tenant_id":1}; UM_distinctid=179597917e7b87-0e9a5b4f03b185-113a6054-13c680-179597917e811fb; CNZZDATA2236244=cnzz_eid=141116805-1600672161-https%3A%2F%2Fcourse.pku.edu.cn%2F&ntime=1620715607; JSESSIONID=E171DBD8ACF6D6D538226307F3EAC36E; _token=774fd0b511f54ab0af699f22b6dcaa7d1e0fa818332f82254fbf29b398fc4578a:2:{i:0;s:6:"_token";i:1;s:433:"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..v6pnPg83mdYu9GngsOIrTUKNlRyYJ6XXI7DQ50wH7U4";}; session_id=DADC8E42C00975C183E83D2416214197; s_session_id=3D012D87533F63778A8142F7E01C7366; web_client_cache_guid=e6a3c5f0-abd0-421c-a7e4-9d10370e132a; thisnotthehopetokenmiaomiaomiao=861901'

headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36',
        'Cookie':bdl_cookie}

# %%
url = 'https://course.pku.edu.cn/webapps/bb-streammedia-hqy-bb_bb60/videoList.action?course_id=%s'%course_d[course_name]
res = requests.get(url,headers=headers)
print('URL part'+str(res.status_code))
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# URL part200
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <html lang="zh-CN-BB">
# <head>
# <title>课堂实录 – Python数据分析(20-21学年第2学期)</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="GET" id="request-method" name="request-method"/>
# <meta content="Blackboard" name="author"/>
# <meta content="© 1997-2021 Blackboard Inc. 保留所有权利。美国专利号：7,493,396 和 7,558,853。其他专利待决。" name="copyright"/>
# <meta content="Blackboard" name="keywords"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
# <link href="/ui/bb-icon2.ico" rel="SHORTCUT ICON" type="image/x-icon"/>
# <link href="/common/shared.css?v=3500.0.6-rel.16+7744aa6" id="css_0" rel="stylesheet" type="text/css"/>
# ...

# %%
data=str(soup.find_all(name='span',attrs={'class':"table-data-cell-value"}))

url_pattern=re.compile(r'<a class="inlineAction".*?href="(.*?)" .*?_blank.*?>',re.S)

url_item_l=re.findall(url_pattern,data)



url_item_l
#[0].replace('amp;','')
# Out:
# ['playVideo.action?hqyCourseId=16581&amp;hqySubId=497361&amp;kcwybm=20212-030-03033930-2106189125-1',
#  'playVideo.action?hqyCourseId=16581&amp;hqySubId=497359&amp;kcwybm=20212-030-03033930-2106189125-1',
#  'playVideo.action?hqyCourseId=16581&amp;hqySubId=497357&amp;kcwybm=20212-030-03033930-2106189125-1',
#  'playVideo.action?hqyCourseId=16581&amp;hqySubId=497355&amp;kcwybm=20212-030-03033930-2106189125-1',
#  'playVideo.action?hqyCourseId=16581&amp;hqySubId=497353&amp;kcwybm=20212-030-03033930-2106189125-1',
#  'playVideo.action?hqyCourseId=16581&amp;hqySubId=497351&amp;kcwybm=20212-030-03033930-2106189125-1',
#  'playVideo.action?hqyCourseId=16581&amp;hqySubId=497349&amp;kcwybm=20212-030-03033930-2106189125-1',
#  'playVideo.action?hqyCourseId=16581&amp;hqySubId=497347&amp;kcwybm=20212-030-03033930-2106189125-1',
#  'playVideo.action?hqyCourseId=16581&amp;hqySubId=497345&amp;kcwybm=20212-030-03033930-2106189125-1',
# ...

# %%
id_pattern=re.compile(r'<a class="inlineAction" href="playVideo.action.hqyCourseId=(.*)&amp;hqySubId=(.*)&amp;kcwybm=.*" target="_blank">')

query_item_l=re.findall(id_pattern,data)

# %% [markdown]
# cookie同上

# %%
vid_cookie='_ga=GA1.3.66611564.1598972936; Hm_lvt_c7896bb34c3be32ea17322b5412545c0=1606471943; PORTALLANG=zh; JWTUser=%7B%22account%22%3A%221800018615%22%2C%22id%22%3A508999%2C%22tenant_id%22%3A1%7D; UM_distinctid=179597917e7b87-0e9a5b4f03b185-113a6054-13c680-179597917e811fb; Hm_lvt_33c7bda3efa65a44890b2247ed5c9747=1620716982,1620716987,1620717005,1620717011; Hm_lpvt_33c7bda3efa65a44890b2247ed5c9747=1620717011; remote_addr=10.42.0.117; user_agent=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10_15_7%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F90.0.4430.93+Safari%2F537.36; tenant_code=1; temp_url=https%3A%2F%2Flivingroomhqy.pku.edu.cn%2Fplayer%3Fcourse_id%3D16581%26sub_id%3D497361; _token=9b5831db59a5c28c1ab0f4fd5a8695b93e89dda5c14e08f244ed45f58864014aa%3A2%3A%7Bi%3A0%3Bs%3A6%3A%22_token%22%3Bi%3A1%3Bs%3A433%3A%22eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..5qOEM_tupn49thG7YNCMsSqH4ok7UU3annQnvfysrPU%22%3B%7D'

# %%
headers2={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36',
        'Cookie':vid_cookie}

# %%
import json

# %%
video_l=[]
for i in range(len(query_item_l)):
    url_='https://livingroomhqy.pku.edu.cn/courseapi/v2/schedule/search-live-course-list?all=1&course_id=%s&sub_id=%s&with_sub_data=1'%query_item_l[i]
    res2 = requests.get(url_,headers=headers2)
    print('URL part'+str(res2.status_code))
    soup2 = BeautifulSoup(res2.text, 'html.parser')
    res2_json=json.loads(res2.text)
    
    video_l.append(eval(res2_json['list'][0]['sub_content'])['save_playback']['contents'])
# Out:
# URL part200
# URL part200
# URL part200
# URL part200
# URL part200
# URL part200
# URL part200
# URL part200
# URL part200
# URL part200
# URL part200

# %%
pd.Series(map(lambda x:x.replace('\\',''),video_l),name=course_name).to_csv('%s_video.csv'%course_name,index=False)

# %% [markdown]
# ## MP4 转写 MP3

# %%
#!conda install moviepy -y

# %%
from moviepy.editor import *
import pandas as pd 

import os 
video_df=pd.read_csv('video.csv',index_col=[0])


head_path='yinpin/'

def get_course(name):
    video_l=video_df[name].tolist()
    os.makedirs(head_path+name,exist_ok=True)
    return video_l

name='信息存储与检索'
video_l=get_course(name)

start,end=map(int,input("输入开始 结束的序号(空隔)").split(" "))
for i in range(start,end):
    video = VideoFileClip(video_l[i].replace('\\',''))
    audio = video.audio
    audio.write_audiofile('%s/%s.wav'%(head_path+name,i))
print('结束')
